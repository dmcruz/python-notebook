# %% [markdown]
# # Pandas Plot

# %%
import yfinance as yf
import pandas as pd

stocklist = ['AMZN', 'GOOG', 'META', 'MSFT', 'NFLX', 'TSLA']

df = pd.DataFrame()

for ticker in stocklist:
    df[ticker] = yf.download(ticker, start='2013-09-01', end='2023-09-30', progress=False)['Close']
df.dropna(axis=0, inplace=True)
df
# Out:
#                   AMZN        GOOG        META        MSFT        NFLX  \
# Date
# 2013-09-03   14.440000   21.429178   41.869999   31.879999   41.285713
# 2013-09-04   14.682000   21.709377   41.779999   31.200001   41.775715
# 2013-09-05   14.705000   21.906887   42.660000   31.230000   42.158569
# 2013-09-06   14.793000   21.907387   43.950001   31.150000   41.648571
# 2013-09-09   14.985500   22.118345   44.040001   31.660000   42.021427
# ...                ...         ...         ...         ...         ...
# 2023-09-25  131.270004  132.169998  300.829987  317.540009  384.799988
# 2023-09-26  125.980003  129.449997  298.959991  312.140015  379.250000
# 2023-09-27  125.980003  131.460007  297.739990  312.790009  377.589996
# 2023-09-28  125.980003  133.130005  303.959991  313.640015  376.359985
# 2023-09-29  127.120003  131.850006  300.209991  315.750000  377.600006
#
#                   TSLA
# Date
# 2013-09-03   11.262667
# 2013-09-04   11.374667
# 2013-09-05   11.328667
# ...

# %%
df.plot(title='Stock Price over 10 Years')
# Out:
# <Axes: title={'center': 'Stock Price over 10 Years'}, xlabel='Date'>

# %% [markdown]
# ## Subplot default format

# %%
df.plot(subplots=True, grid=True)
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>, <Axes: xlabel='Date'>], dtype=object)

# %% [markdown]
# ## Subplots in 2x3 layout

# %%
df.plot(subplots=True, layout=(2,3), title='Stock Prices over 10 Years', grid=True)
# Out:
# array([[<Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#         <Axes: xlabel='Date'>],
#        [<Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#         <Axes: xlabel='Date'>]], dtype=object)

# %% [markdown]
# ## Price Changes

# %%
price_changes_daily = df.pct_change()

price_changes_daily.plot(subplots=True, layout=(2, 3), title="Stock Prices over 10 Years", grid=True)
# Out:
# array([[<Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#         <Axes: xlabel='Date'>],
#        [<Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#         <Axes: xlabel='Date'>]], dtype=object)

# %%
(1 + price_changes_daily).cumprod() #Compounded price change
# Out:
#                 AMZN      GOOG      META      MSFT      NFLX       TSLA
# Date
# 2013-09-03       NaN       NaN       NaN       NaN       NaN        NaN
# 2013-09-04  1.016759  1.013076  0.997850  0.978670  1.011869   1.009944
# 2013-09-05  1.018352  1.022292  1.018868  0.979611  1.021142   1.005860
# 2013-09-06  1.024446  1.022316  1.049678  0.977102  1.008789   0.988339
# 2013-09-09  1.037777  1.032160  1.051827  0.993099  1.017820   0.951225
# ...              ...       ...       ...       ...       ...        ...
# 2023-09-25  9.090721  6.167759  7.184858  9.960477  9.320415  21.929976
# 2023-09-26  8.724377  6.040829  7.140196  9.791092  9.185986  21.675150
# 2023-09-27  8.724377  6.134627  7.111058  9.811481  9.145779  21.353735
# 2023-09-28  8.724377  6.212558  7.259613  9.838144  9.115986  21.875814
# 2023-09-29  8.803325  6.152826  7.170050  9.904329  9.146021  22.216763
#
# [2537 rows x 6 columns]

# %%
(1 + price_changes_daily).cumprod().plot(title='Performance of Stocks over Time', ylabel='Price', grid=True)
# Out:
# <Axes: title={'center': 'Performance of Stocks over Time'}, xlabel='Date', ylabel='Price'>
